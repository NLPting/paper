# %%
import sys
sys.path.append("..")
import numpy as np
import keras.backend as K
import nea.asap_reader as dataset 
from nea.asap_reader import read_org_dataset
import nea.utils as U
import os
from time import time
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.gpu_options.visible_device_list = "0"
set_session(tf.Session(config=config))
# Out:
# /home/nlplab/ting/anaconda3/envs/elmobilstm/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
train_path = '../../data/fold_0/train.tsv'
dev_path = '../../data/fold_0/dev.tsv'
test_path = '../../data/fold_0/test.tsv'
GLOVE_DIR = "../../../embeddings/glove/"
out_dir = 'output'
vocab_size = 4000
maxlen = 0
prompt_id = int(1)
w = np.load('my_level_vocab.npy').item()

# %%
#embeddings_index = {}
#f = open(os.path.join(GLOVE_DIR, 'glove.6B.50d.txt'), encoding = 'utf-8')
#for line in f:
#    values = line.split()
#    word = values[0]
#    coefs = np.asarray(values[1:], dtype='float32')
#    embeddings_index[word] = coefs
#f.close()

# %%
#embedding_matrix_glove = np.zeros((len(vocab), 50))
#for word, i in vocab.items():
#    embedding_vector = embeddings_index.get(word)
#    if embedding_vector is not None:
#        embedding_matrix_glove[i] = embedding_vector
#print('Null word embeddings: %d' % np.sum(np.sum(embedding_matrix_glove, axis=1) == 0))

# %%
from keras.preprocessing import sequence
# data_x is a list of lists
(train_x, train_y, train_pmt), (dev_x, dev_y, dev_pmt), (test_x, test_y, test_pmt), vocab, vocab_size, overal_maxlen, num_outputs = dataset.get_data(
(train_path, dev_path, test_path), prompt_id, vocab_size, maxlen, tokenize_text=True, to_lower=True, sort_by_len=False, vocab_path=None)

# %%
from keras.preprocessing import sequence
train_x = sequence.pad_sequences(train_x, maxlen=overal_maxlen)
dev_x = sequence.pad_sequences(dev_x, maxlen=overal_maxlen)
test_x = sequence.pad_sequences(test_x, maxlen=overal_maxlen)

# %%
train_y = np.array(train_y, dtype=K.floatx())
dev_y = np.array(dev_y, dtype=K.floatx())
test_y = np.array(test_y, dtype=K.floatx())
train_pmt = np.array(train_pmt, dtype='int32')
dev_pmt = np.array(dev_pmt, dtype='int32')
test_pmt = np.array(test_pmt, dtype='int32')
# We need the dev and test sets in the original scale for evaluation
dev_y_org = dev_y.astype(dataset.get_ref_dtype())
test_y_org = test_y.astype(dataset.get_ref_dtype())
# Convert scores to boundary of [0 1] for training and evaluation (loss calculation)
train_y = dataset.get_model_friendly_scores(train_y, train_pmt)
dev_y = dataset.get_model_friendly_scores(dev_y, dev_pmt)
test_y = dataset.get_model_friendly_scores(test_y, test_pmt)

# %%
from keras.models import Sequential, Model , Input
from keras.layers import Dense, Embedding, Activation , Flatten  , concatenate
from keras.layers.merge import Concatenate
from keras.layers import Dropout, GlobalAveragePooling1D ,GlobalMaxPooling1D , MaxPooling1D
from keras.layers import LSTM , Bidirectional , Convolution1D
from nea.optimizers import get_optimizer
from dl_text import rd_ft
import textstat

# %%
train_org = read_org_dataset(train_path , prompt_id ,tokenize_text=True, to_lower=True )
dev_org = read_org_dataset(dev_path , prompt_id ,tokenize_text=True, to_lower=True )
test_org = read_org_dataset(test_path , prompt_id ,tokenize_text=True, to_lower=True )

# %%
def lg_feature(org_array):
    return len(org_array)
def lg_level_feature(org_array):
    return len([word for word in org_array if word in w])
def differe_level_feature(org_array , delete_key=['A1']):
    feature_map = {'A1':0,'A2':0,'B1':0,'B2':0,'C1':0,'C2':0}
    for word in org_array:
        if word in w:
            if w[word]=='A1':feature_map['A1']+=1
            if w[word]=='A2':feature_map['A2']+=1
            if w[word]=='B1':feature_map['B1']+=1
            if w[word]=='B2':feature_map['B2']+=1
            if w[word]=='C1':feature_map['C1']+=1
            if w[word]=='C2':feature_map['C2']+=1
    #print(feature_map)
    F = [feature_map[key] for key in feature_map.keys() if key not in delete_key]
    return F  
def get_feature(org_array):
    corpus = ' '.join(org_array)
    f1 = lg_feature(org_array)
    f2 = lg_level_feature(org_array)
    f3 = differe_level_feature(org_array)
    f4 = textstat.flesch_reading_ease(corpus)
    f5 = textstat.smog_index(corpus)
    f6 = textstat.flesch_kincaid_grade(corpus)
    f7 = textstat.coleman_liau_index(corpus)
    f8 = textstat.automated_readability_index(corpus)
    f9 = textstat.dale_chall_readability_score(corpus)
    f10 = textstat.difficult_words(corpus)
    f11 = textstat.linsear_write_formula(corpus)
    f12 = textstat.gunning_fog(corpus)
    F = [f2,*f3,f6,f7,f8,f9,f10,f11,f12]
    #F = [f2,*f3 , f6  , f8 , f9 , f10]
    #F = [f2,*f3]
    return F

# %%
train_f = np.array([get_feature(x) for x in train_org] , dtype=K.floatx())
dev_f =  np.array([get_feature(x) for x in dev_org] , dtype=K.floatx())
test_f = np.array([get_feature(x) for x in test_org] , dtype=K.floatx())

# %%
main_input = Input(shape=(overal_maxlen,), dtype='float64')
embedder = Embedding(len(vocab), 50, input_length = overal_maxlen) 
#embedder = (Embedding(len(vocab),50,weights=[embedding_matrix_glove],input_length=overal_maxlen,trainable=True))
embed = embedder(main_input)
cnn1 = Convolution1D(filters=50 ,kernel_size=3)(embed)
flat = Flatten()(cnn1)
#global1 = GlobalAveragePooling1D()(cnn1)
######################
Other_Input = Input(shape=(len(train_f[0]),))
add_feature = concatenate([flat, Other_Input],axis=1)
##########################################
#add_feature = Dropout(0.5)(add_feature)
main_output = Dense(1, activation='sigmoid')(add_feature)

model = Model(inputs = [main_input , Other_Input], outputs = main_output)

# %%
loss = 'mean_squared_error'
metric = 'mean_absolute_error'
opt = get_optimizer('adam')

# %%
model.compile(loss=loss,
              optimizer=opt,
              metrics=[metric])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 939)          0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 939, 50)      200000      input_3[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 937, 50)      7550        embedding_2[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 46850)        0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 13)           0
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 46863)        0           flatten_2[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            46864       concatenate_2[0][0]
# ==================================================================================================
# Total params: 254,414
# Trainable params: 254,414
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from nea.evalute_twoinput import Evaluator 
evl = Evaluator (dataset, prompt_id, out_dir, dev_x , dev_f  ,test_x , test_f , dev_y, test_y, dev_y_org, test_y_org)
evl.evaluate(model, -1, print_info=True)
# Out:
# [Dev]   loss: 0.0252, metric: 0.1314, mean: 9.553 (8.508), stdev: 0.440 (1.539)
# [Test]  loss: 0.0267, metric: 0.1321, mean: 9.531 (8.473), stdev: 0.397 (1.538)
# [DEV]   QWK:  0.328, LWK: 0.166, PRS: 0.836, SPR: 0.802, Tau: 0.659 (Best @ -1: {{0.328}}, 0.166, 0.836, 0.802, 0.659)
# [TEST]  QWK:  0.279, LWK: 0.151, PRS: 0.796, SPR: 0.772, Tau: 0.630 (Best @ -1: {{0.279}}, 0.151, 0.796, 0.772, 0.630)
# --------------------------------------------------------------------------------------------------------------------------

# %%
total_train_time = 0
total_eval_time = 0
best , count = 0 , 0
for ii in range(50):
    # Training
    t0 = time()
    train_history = model.fit([train_x , train_f], train_y, batch_size=32, epochs=1, verbose=1)
    #train_history = model.fit([train_f], train_y, batch_size=32, epochs=1, verbose=1)
    tr_time = time() - t0
    total_train_time += tr_time
    # Evaluate
    t0 = time()
    evl.evaluate(model, ii)
    evl_time = time() - t0
    total_eval_time += evl_time
    train_loss = train_history.history['loss'][0]
    train_metric = train_history.history[metric][0]
    print('Epoch %d, train: %is, evaluation: %is' % (ii, tr_time, evl_time))
    print('[Train] loss: %.4f, metric: %.4f' % (train_loss, train_metric))
    evl.print_info()
    
evl.print_final_info()
# Out:
# Epoch 1/1
# 1070/1070 [==============================] - 0s 275us/step - loss: 0.0134 - mean_absolute_error: 0.0891
# Epoch 0, train: 0s, evaluation: 0s
# [Train] loss: 0.0134, metric: 0.0891
# [Dev]   loss: 0.0089, metric: 0.0768, mean: 9.015 (8.508), stdev: 1.292 (1.539)
# [Test]  loss: 0.0087, metric: 0.0752, mean: 8.950 (8.473), stdev: 1.275 (1.538)
# [DEV]   QWK:  0.775, LWK: 0.542, PRS: 0.856, SPR: 0.843, Tau: 0.708 (Best @ 0: {{0.775}}, 0.542, 0.856, 0.843, 0.708)
# [TEST]  QWK:  0.787, LWK: 0.563, PRS: 0.853, SPR: 0.827, Tau: 0.689 (Best @ 0: {{0.787}}, 0.563, 0.853, 0.827, 0.689)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 157us/step - loss: 0.0043 - mean_absolute_error: 0.0518
# Epoch 1, train: 0s, evaluation: 0s
# [Train] loss: 0.0043, metric: 0.0518
# [Dev]   loss: 0.0062, metric: 0.0609, mean: 8.448 (8.508), stdev: 1.325 (1.539)
# [Test]  loss: 0.0063, metric: 0.0606, mean: 8.378 (8.473), stdev: 1.314 (1.538)
# [DEV]   QWK:  0.830, LWK: 0.638, PRS: 0.861, SPR: 0.841, Tau: 0.705 (Best @ 1: {{0.830}}, 0.638, 0.861, 0.841, 0.705)
# [TEST]  QWK:  0.812, LWK: 0.614, PRS: 0.860, SPR: 0.832, Tau: 0.696 (Best @ 1: {{0.812}}, 0.614, 0.860, 0.832, 0.696)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 155us/step - loss: 0.0020 - mean_absolute_error: 0.0350
# Epoch 2, train: 0s, evaluation: 0s
# [Train] loss: 0.0020, metric: 0.0350
# [Dev]   loss: 0.0065, metric: 0.0635, mean: 8.646 (8.508), stdev: 1.247 (1.539)
# [Test]  loss: 0.0065, metric: 0.0626, mean: 8.589 (8.473), stdev: 1.243 (1.538)
# [DEV]   QWK:  0.819, LWK: 0.616, PRS: 0.857, SPR: 0.835, Tau: 0.698 (Best @ 1: {{0.830}}, 0.638, 0.861, 0.841, 0.705)
# [TEST]  QWK:  0.830, LWK: 0.632, PRS: 0.858, SPR: 0.827, Tau: 0.690 (Best @ 1: {{0.812}}, 0.614, 0.860, 0.832, 0.696)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 149us/step - loss: 0.0014 - mean_absolute_error: 0.0297
# Epoch 3, train: 0s, evaluation: 0s
# [Train] loss: 0.0014, metric: 0.0297
# [Dev]   loss: 0.0063, metric: 0.0624, mean: 8.444 (8.508), stdev: 1.353 (1.539)
# [Test]  loss: 0.0064, metric: 0.0615, mean: 8.376 (8.473), stdev: 1.342 (1.538)
# [DEV]   QWK:  0.840, LWK: 0.649, PRS: 0.858, SPR: 0.837, Tau: 0.701 (Best @ 3: {{0.840}}, 0.649, 0.858, 0.837, 0.701)
# [TEST]  QWK:  0.819, LWK: 0.622, PRS: 0.857, SPR: 0.827, Tau: 0.690 (Best @ 3: {{0.819}}, 0.622, 0.857, 0.827, 0.690)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 146us/step - loss: 9.3303e-04 - mean_absolute_error: 0.0235
# Epoch 4, train: 0s, evaluation: 0s
# [Train] loss: 0.0009, metric: 0.0235
# [Dev]   loss: 0.0067, metric: 0.0647, mean: 8.732 (8.508), stdev: 1.321 (1.539)
# [Test]  loss: 0.0066, metric: 0.0636, mean: 8.667 (8.473), stdev: 1.316 (1.538)
# [DEV]   QWK:  0.820, LWK: 0.612, PRS: 0.860, SPR: 0.836, Tau: 0.699 (Best @ 3: {{0.840}}, 0.649, 0.858, 0.837, 0.701)
# [TEST]  QWK:  0.830, LWK: 0.633, PRS: 0.859, SPR: 0.828, Tau: 0.691 (Best @ 3: {{0.819}}, 0.622, 0.857, 0.827, 0.690)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 149us/step - loss: 5.0938e-04 - mean_absolute_error: 0.0162
# Epoch 5, train: 0s, evaluation: 0s
# [Train] loss: 0.0005, metric: 0.0162
# [Dev]   loss: 0.0065, metric: 0.0633, mean: 8.337 (8.508), stdev: 1.366 (1.539)
# [Test]  loss: 0.0067, metric: 0.0627, mean: 8.277 (8.473), stdev: 1.360 (1.538)
# [DEV]   QWK:  0.835, LWK: 0.631, PRS: 0.860, SPR: 0.836, Tau: 0.698 (Best @ 3: {{0.840}}, 0.649, 0.858, 0.837, 0.701)
# [TEST]  QWK:  0.808, LWK: 0.598, PRS: 0.858, SPR: 0.827, Tau: 0.690 (Best @ 3: {{0.819}}, 0.622, 0.857, 0.827, 0.690)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 144us/step - loss: 5.0578e-04 - mean_absolute_error: 0.0170
# Epoch 6, train: 0s, evaluation: 0s
# [Train] loss: 0.0005, metric: 0.0170
# [Dev]   loss: 0.0062, metric: 0.0621, mean: 8.571 (8.508), stdev: 1.362 (1.539)
# [Test]  loss: 0.0062, metric: 0.0615, mean: 8.507 (8.473), stdev: 1.358 (1.538)
# [DEV]   QWK:  0.841, LWK: 0.636, PRS: 0.860, SPR: 0.836, Tau: 0.699 (Best @ 6: {{0.841}}, 0.636, 0.860, 0.836, 0.699)
# [TEST]  QWK:  0.843, LWK: 0.655, PRS: 0.859, SPR: 0.828, Tau: 0.691 (Best @ 6: {{0.843}}, 0.655, 0.859, 0.828, 0.691)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 148us/step - loss: 7.1788e-04 - mean_absolute_error: 0.0204
# Epoch 7, train: 0s, evaluation: 0s
# [Train] loss: 0.0007, metric: 0.0204
# [Dev]   loss: 0.0070, metric: 0.0668, mean: 8.797 (8.508), stdev: 1.340 (1.539)
# [Test]  loss: 0.0069, metric: 0.0653, mean: 8.731 (8.473), stdev: 1.335 (1.538)
# [DEV]   QWK:  0.818, LWK: 0.597, PRS: 0.860, SPR: 0.837, Tau: 0.699 (Best @ 6: {{0.841}}, 0.636, 0.860, 0.836, 0.699)
# [TEST]  QWK:  0.827, LWK: 0.626, PRS: 0.859, SPR: 0.827, Tau: 0.690 (Best @ 6: {{0.843}}, 0.655, 0.859, 0.828, 0.691)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 148us/step - loss: 0.0015 - mean_absolute_error: 0.0304
# Epoch 8, train: 0s, evaluation: 0s
# [Train] loss: 0.0015, metric: 0.0304
# [Dev]   loss: 0.0067, metric: 0.0645, mean: 8.317 (8.508), stdev: 1.424 (1.539)
# [Test]  loss: 0.0068, metric: 0.0641, mean: 8.253 (8.473), stdev: 1.418 (1.538)
# [DEV]   QWK:  0.840, LWK: 0.640, PRS: 0.858, SPR: 0.837, Tau: 0.699 (Best @ 6: {{0.841}}, 0.636, 0.860, 0.836, 0.699)
# [TEST]  QWK:  0.817, LWK: 0.612, PRS: 0.858, SPR: 0.829, Tau: 0.692 (Best @ 6: {{0.843}}, 0.655, 0.859, 0.828, 0.691)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 147us/step - loss: 0.0020 - mean_absolute_error: 0.0344
# Epoch 9, train: 0s, evaluation: 0s
# [Train] loss: 0.0020, metric: 0.0344
# [Dev]   loss: 0.0065, metric: 0.0640, mean: 8.720 (8.508), stdev: 1.301 (1.539)
# [Test]  loss: 0.0066, metric: 0.0634, mean: 8.660 (8.473), stdev: 1.289 (1.538)
# [DEV]   QWK:  0.826, LWK: 0.617, PRS: 0.863, SPR: 0.840, Tau: 0.704 (Best @ 6: {{0.841}}, 0.636, 0.860, 0.836, 0.699)
# [TEST]  QWK:  0.832, LWK: 0.634, PRS: 0.859, SPR: 0.830, Tau: 0.693 (Best @ 6: {{0.843}}, 0.655, 0.859, 0.828, 0.691)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 146us/step - loss: 0.0013 - mean_absolute_error: 0.0275
# Epoch 10, train: 0s, evaluation: 0s
# [Train] loss: 0.0013, metric: 0.0275
# [Dev]   loss: 0.0062, metric: 0.0621, mean: 8.478 (8.508), stdev: 1.434 (1.539)
# [Test]  loss: 0.0063, metric: 0.0612, mean: 8.417 (8.473), stdev: 1.432 (1.538)
# [DEV]   QWK:  0.851, LWK: 0.656, PRS: 0.863, SPR: 0.842, Tau: 0.706 (Best @ 10: {{0.851}}, 0.656, 0.863, 0.842, 0.706)
# [TEST]  QWK:  0.845, LWK: 0.653, PRS: 0.861, SPR: 0.833, Tau: 0.697 (Best @ 10: {{0.845}}, 0.653, 0.861, 0.833, 0.697)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 151us/step - loss: 0.0010 - mean_absolute_error: 0.0248
# Epoch 11, train: 0s, evaluation: 0s
# [Train] loss: 0.0010, metric: 0.0248
# [Dev]   loss: 0.0061, metric: 0.0611, mean: 8.477 (8.508), stdev: 1.326 (1.539)
# [Test]  loss: 0.0062, metric: 0.0604, mean: 8.417 (8.473), stdev: 1.320 (1.538)
# [DEV]   QWK:  0.839, LWK: 0.637, PRS: 0.862, SPR: 0.836, Tau: 0.700 (Best @ 10: {{0.851}}, 0.656, 0.863, 0.842, 0.706)
# [TEST]  QWK:  0.833, LWK: 0.643, PRS: 0.861, SPR: 0.832, Tau: 0.695 (Best @ 10: {{0.845}}, 0.653, 0.861, 0.833, 0.697)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 149us/step - loss: 7.3364e-04 - mean_absolute_error: 0.0203
# Epoch 12, train: 0s, evaluation: 0s
# [Train] loss: 0.0007, metric: 0.0203
# [Dev]   loss: 0.0060, metric: 0.0613, mean: 8.553 (8.508), stdev: 1.375 (1.539)
# [Test]  loss: 0.0061, metric: 0.0606, mean: 8.491 (8.473), stdev: 1.369 (1.538)
# [DEV]   QWK:  0.846, LWK: 0.641, PRS: 0.864, SPR: 0.841, Tau: 0.705 (Best @ 10: {{0.851}}, 0.656, 0.863, 0.842, 0.706)
# [TEST]  QWK:  0.853, LWK: 0.668, PRS: 0.862, SPR: 0.832, Tau: 0.695 (Best @ 10: {{0.845}}, 0.653, 0.861, 0.833, 0.697)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 149us/step - loss: 4.3696e-04 - mean_absolute_error: 0.0148
# Epoch 13, train: 0s, evaluation: 0s
# [Train] loss: 0.0004, metric: 0.0148
# [Dev]   loss: 0.0065, metric: 0.0640, mean: 8.717 (8.508), stdev: 1.386 (1.539)
# [Test]  loss: 0.0065, metric: 0.0629, mean: 8.655 (8.473), stdev: 1.383 (1.538)
# [DEV]   QWK:  0.823, LWK: 0.611, PRS: 0.862, SPR: 0.841, Tau: 0.705 (Best @ 10: {{0.851}}, 0.656, 0.863, 0.842, 0.706)
# [TEST]  QWK:  0.850, LWK: 0.666, PRS: 0.862, SPR: 0.832, Tau: 0.696 (Best @ 10: {{0.845}}, 0.653, 0.861, 0.833, 0.697)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 151us/step - loss: 5.0060e-04 - mean_absolute_error: 0.0170
# Epoch 14, train: 0s, evaluation: 0s
# [Train] loss: 0.0005, metric: 0.0170
# [Dev]   loss: 0.0061, metric: 0.0612, mean: 8.404 (8.508), stdev: 1.380 (1.539)
# [Test]  loss: 0.0064, metric: 0.0615, mean: 8.339 (8.473), stdev: 1.376 (1.538)
# [DEV]   QWK:  0.844, LWK: 0.647, PRS: 0.865, SPR: 0.838, Tau: 0.702 (Best @ 10: {{0.851}}, 0.656, 0.863, 0.842, 0.706)
# [TEST]  QWK:  0.819, LWK: 0.619, PRS: 0.860, SPR: 0.830, Tau: 0.694 (Best @ 10: {{0.845}}, 0.653, 0.861, 0.833, 0.697)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 148us/step - loss: 7.0788e-04 - mean_absolute_error: 0.0204
# Epoch 15, train: 0s, evaluation: 0s
# [Train] loss: 0.0007, metric: 0.0204
# [Dev]   loss: 0.0081, metric: 0.0730, mean: 8.953 (8.508), stdev: 1.381 (1.539)
# [Test]  loss: 0.0078, metric: 0.0703, mean: 8.888 (8.473), stdev: 1.386 (1.538)
# [DEV]   QWK:  0.805, LWK: 0.573, PRS: 0.862, SPR: 0.840, Tau: 0.704 (Best @ 10: {{0.851}}, 0.656, 0.863, 0.842, 0.706)
# [TEST]  QWK:  0.809, LWK: 0.588, PRS: 0.862, SPR: 0.833, Tau: 0.697 (Best @ 10: {{0.845}}, 0.653, 0.861, 0.833, 0.697)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 146us/step - loss: 8.1371e-04 - mean_absolute_error: 0.0216
# Epoch 16, train: 0s, evaluation: 0s
# [Train] loss: 0.0008, metric: 0.0216
# [Dev]   loss: 0.0062, metric: 0.0623, mean: 8.654 (8.508), stdev: 1.373 (1.539)
# [Test]  loss: 0.0062, metric: 0.0615, mean: 8.595 (8.473), stdev: 1.368 (1.538)
# [DEV]   QWK:  0.834, LWK: 0.628, PRS: 0.864, SPR: 0.840, Tau: 0.703 (Best @ 10: {{0.851}}, 0.656, 0.863, 0.842, 0.706)
# [TEST]  QWK:  0.851, LWK: 0.670, PRS: 0.862, SPR: 0.834, Tau: 0.698 (Best @ 10: {{0.845}}, 0.653, 0.861, 0.833, 0.697)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 149us/step - loss: 5.7916e-04 - mean_absolute_error: 0.0182
# Epoch 17, train: 0s, evaluation: 0s
# [Train] loss: 0.0006, metric: 0.0182
# [Dev]   loss: 0.0061, metric: 0.0609, mean: 8.382 (8.508), stdev: 1.359 (1.539)
# [Test]  loss: 0.0064, metric: 0.0612, mean: 8.319 (8.473), stdev: 1.352 (1.538)
# [DEV]   QWK:  0.843, LWK: 0.644, PRS: 0.867, SPR: 0.840, Tau: 0.704 (Best @ 10: {{0.851}}, 0.656, 0.863, 0.842, 0.706)
# [TEST]  QWK:  0.821, LWK: 0.626, PRS: 0.861, SPR: 0.833, Tau: 0.697 (Best @ 10: {{0.845}}, 0.653, 0.861, 0.833, 0.697)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 146us/step - loss: 4.5863e-04 - mean_absolute_error: 0.0160
# Epoch 18, train: 0s, evaluation: 0s
# [Train] loss: 0.0005, metric: 0.0160
# [Dev]   loss: 0.0062, metric: 0.0619, mean: 8.642 (8.508), stdev: 1.384 (1.539)
# [Test]  loss: 0.0062, metric: 0.0612, mean: 8.580 (8.473), stdev: 1.379 (1.538)
# [DEV]   QWK:  0.832, LWK: 0.629, PRS: 0.865, SPR: 0.842, Tau: 0.706 (Best @ 10: {{0.851}}, 0.656, 0.863, 0.842, 0.706)
# [TEST]  QWK:  0.852, LWK: 0.663, PRS: 0.862, SPR: 0.834, Tau: 0.698 (Best @ 10: {{0.845}}, 0.653, 0.861, 0.833, 0.697)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 149us/step - loss: 5.0201e-04 - mean_absolute_error: 0.0172
# Epoch 19, train: 0s, evaluation: 0s
# [Train] loss: 0.0005, metric: 0.0172
# [Dev]   loss: 0.0062, metric: 0.0620, mean: 8.656 (8.508), stdev: 1.387 (1.539)
# [Test]  loss: 0.0062, metric: 0.0615, mean: 8.593 (8.473), stdev: 1.384 (1.538)
# [DEV]   QWK:  0.834, LWK: 0.629, PRS: 0.865, SPR: 0.840, Tau: 0.704 (Best @ 10: {{0.851}}, 0.656, 0.863, 0.842, 0.706)
# [TEST]  QWK:  0.853, LWK: 0.661, PRS: 0.863, SPR: 0.833, Tau: 0.697 (Best @ 10: {{0.845}}, 0.653, 0.861, 0.833, 0.697)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 146us/step - loss: 5.9602e-04 - mean_absolute_error: 0.0186
# Epoch 20, train: 0s, evaluation: 0s
# [Train] loss: 0.0006, metric: 0.0186
# [Dev]   loss: 0.0060, metric: 0.0606, mean: 8.584 (8.508), stdev: 1.358 (1.539)
# [Test]  loss: 0.0061, metric: 0.0607, mean: 8.526 (8.473), stdev: 1.354 (1.538)
# [DEV]   QWK:  0.840, LWK: 0.643, PRS: 0.866, SPR: 0.840, Tau: 0.704 (Best @ 10: {{0.851}}, 0.656, 0.863, 0.842, 0.706)
# [TEST]  QWK:  0.855, LWK: 0.663, PRS: 0.862, SPR: 0.833, Tau: 0.696 (Best @ 10: {{0.845}}, 0.653, 0.861, 0.833, 0.697)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 145us/step - loss: 6.3067e-04 - mean_absolute_error: 0.0192
# Epoch 21, train: 0s, evaluation: 0s
# [Train] loss: 0.0006, metric: 0.0192
# [Dev]   loss: 0.0060, metric: 0.0609, mean: 8.497 (8.508), stdev: 1.407 (1.539)
# [Test]  loss: 0.0062, metric: 0.0607, mean: 8.434 (8.473), stdev: 1.402 (1.538)
# [DEV]   QWK:  0.852, LWK: 0.655, PRS: 0.866, SPR: 0.841, Tau: 0.705 (Best @ 21: {{0.852}}, 0.655, 0.866, 0.841, 0.705)
# [TEST]  QWK:  0.844, LWK: 0.651, PRS: 0.861, SPR: 0.832, Tau: 0.696 (Best @ 21: {{0.844}}, 0.651, 0.861, 0.832, 0.696)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 148us/step - loss: 6.8429e-04 - mean_absolute_error: 0.0196
# Epoch 22, train: 0s, evaluation: 0s
# [Train] loss: 0.0007, metric: 0.0196
# [Dev]   loss: 0.0078, metric: 0.0694, mean: 8.067 (8.508), stdev: 1.341 (1.539)
# [Test]  loss: 0.0083, metric: 0.0716, mean: 8.005 (8.473), stdev: 1.334 (1.538)
# [DEV]   QWK:  0.811, LWK: 0.592, PRS: 0.868, SPR: 0.839, Tau: 0.704 (Best @ 21: {{0.852}}, 0.655, 0.866, 0.841, 0.705)
# [TEST]  QWK:  0.796, LWK: 0.587, PRS: 0.861, SPR: 0.832, Tau: 0.696 (Best @ 21: {{0.844}}, 0.651, 0.861, 0.832, 0.696)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 149us/step - loss: 0.0011 - mean_absolute_error: 0.0270
# Epoch 23, train: 0s, evaluation: 0s
# [Train] loss: 0.0011, metric: 0.0270
# [Dev]   loss: 0.0061, metric: 0.0618, mean: 8.675 (8.508), stdev: 1.380 (1.539)
# [Test]  loss: 0.0064, metric: 0.0616, mean: 8.616 (8.473), stdev: 1.376 (1.538)
# [DEV]   QWK:  0.839, LWK: 0.633, PRS: 0.869, SPR: 0.846, Tau: 0.711 (Best @ 21: {{0.852}}, 0.655, 0.866, 0.841, 0.705)
# [TEST]  QWK:  0.844, LWK: 0.656, PRS: 0.861, SPR: 0.834, Tau: 0.697 (Best @ 21: {{0.844}}, 0.651, 0.861, 0.832, 0.696)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 149us/step - loss: 0.0016 - mean_absolute_error: 0.0315
# Epoch 24, train: 0s, evaluation: 0s
# [Train] loss: 0.0016, metric: 0.0315
# [Dev]   loss: 0.0060, metric: 0.0606, mean: 8.410 (8.508), stdev: 1.403 (1.539)
# [Test]  loss: 0.0063, metric: 0.0610, mean: 8.344 (8.473), stdev: 1.390 (1.538)
# [DEV]   QWK:  0.856, LWK: 0.674, PRS: 0.868, SPR: 0.843, Tau: 0.707 (Best @ 24: {{0.856}}, 0.674, 0.868, 0.843, 0.707)
# [TEST]  QWK:  0.828, LWK: 0.632, PRS: 0.862, SPR: 0.835, Tau: 0.698 (Best @ 24: {{0.828}}, 0.632, 0.862, 0.835, 0.698)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 150us/step - loss: 8.9621e-04 - mean_absolute_error: 0.0228
# Epoch 25, train: 0s, evaluation: 0s
# [Train] loss: 0.0009, metric: 0.0228
# [Dev]   loss: 0.0059, metric: 0.0603, mean: 8.468 (8.508), stdev: 1.386 (1.539)
# [Test]  loss: 0.0061, metric: 0.0604, mean: 8.406 (8.473), stdev: 1.383 (1.538)
# [DEV]   QWK:  0.851, LWK: 0.659, PRS: 0.867, SPR: 0.843, Tau: 0.707 (Best @ 24: {{0.856}}, 0.674, 0.868, 0.843, 0.707)
# [TEST]  QWK:  0.836, LWK: 0.646, PRS: 0.862, SPR: 0.835, Tau: 0.698 (Best @ 24: {{0.828}}, 0.632, 0.862, 0.835, 0.698)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 149us/step - loss: 4.1583e-04 - mean_absolute_error: 0.0148
# Epoch 26, train: 0s, evaluation: 0s
# [Train] loss: 0.0004, metric: 0.0148
# [Dev]   loss: 0.0059, metric: 0.0599, mean: 8.544 (8.508), stdev: 1.374 (1.539)
# [Test]  loss: 0.0060, metric: 0.0601, mean: 8.481 (8.473), stdev: 1.374 (1.538)
# [DEV]   QWK:  0.851, LWK: 0.655, PRS: 0.868, SPR: 0.844, Tau: 0.709 (Best @ 24: {{0.856}}, 0.674, 0.868, 0.843, 0.707)
# [TEST]  QWK:  0.856, LWK: 0.669, PRS: 0.863, SPR: 0.836, Tau: 0.699 (Best @ 24: {{0.828}}, 0.632, 0.862, 0.835, 0.698)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 148us/step - loss: 2.8002e-04 - mean_absolute_error: 0.0117
# Epoch 27, train: 0s, evaluation: 0s
# [Train] loss: 0.0003, metric: 0.0117
# [Dev]   loss: 0.0059, metric: 0.0600, mean: 8.550 (8.508), stdev: 1.383 (1.539)
# [Test]  loss: 0.0061, metric: 0.0602, mean: 8.492 (8.473), stdev: 1.381 (1.538)
# [DEV]   QWK:  0.847, LWK: 0.650, PRS: 0.868, SPR: 0.844, Tau: 0.709 (Best @ 24: {{0.856}}, 0.674, 0.868, 0.843, 0.707)
# [TEST]  QWK:  0.856, LWK: 0.668, PRS: 0.863, SPR: 0.835, Tau: 0.698 (Best @ 24: {{0.828}}, 0.632, 0.862, 0.835, 0.698)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 145us/step - loss: 1.8610e-04 - mean_absolute_error: 0.0089
# Epoch 28, train: 0s, evaluation: 0s
# [Train] loss: 0.0002, metric: 0.0089
# [Dev]   loss: 0.0058, metric: 0.0597, mean: 8.506 (8.508), stdev: 1.373 (1.539)
# [Test]  loss: 0.0061, metric: 0.0601, mean: 8.445 (8.473), stdev: 1.371 (1.538)
# [DEV]   QWK:  0.853, LWK: 0.663, PRS: 0.869, SPR: 0.843, Tau: 0.707 (Best @ 24: {{0.856}}, 0.674, 0.868, 0.843, 0.707)
# [TEST]  QWK:  0.838, LWK: 0.643, PRS: 0.863, SPR: 0.836, Tau: 0.699 (Best @ 24: {{0.828}}, 0.632, 0.862, 0.835, 0.698)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 148us/step - loss: 1.4610e-04 - mean_absolute_error: 0.0081
# Epoch 29, train: 0s, evaluation: 0s
# [Train] loss: 0.0001, metric: 0.0081
# [Dev]   loss: 0.0060, metric: 0.0610, mean: 8.643 (8.508), stdev: 1.356 (1.539)
# [Test]  loss: 0.0062, metric: 0.0611, mean: 8.585 (8.473), stdev: 1.355 (1.538)
# [DEV]   QWK:  0.841, LWK: 0.637, PRS: 0.868, SPR: 0.842, Tau: 0.707 (Best @ 24: {{0.856}}, 0.674, 0.868, 0.843, 0.707)
# [TEST]  QWK:  0.850, LWK: 0.661, PRS: 0.863, SPR: 0.835, Tau: 0.698 (Best @ 24: {{0.828}}, 0.632, 0.862, 0.835, 0.698)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 144us/step - loss: 1.4196e-04 - mean_absolute_error: 0.0082
# Epoch 30, train: 0s, evaluation: 0s
# [Train] loss: 0.0001, metric: 0.0082
# [Dev]   loss: 0.0059, metric: 0.0603, mean: 8.632 (8.508), stdev: 1.367 (1.539)
# [Test]  loss: 0.0062, metric: 0.0610, mean: 8.568 (8.473), stdev: 1.365 (1.538)
# [DEV]   QWK:  0.834, LWK: 0.628, PRS: 0.869, SPR: 0.843, Tau: 0.707 (Best @ 24: {{0.856}}, 0.674, 0.868, 0.843, 0.707)
# [TEST]  QWK:  0.848, LWK: 0.657, PRS: 0.863, SPR: 0.834, Tau: 0.697 (Best @ 24: {{0.828}}, 0.632, 0.862, 0.835, 0.698)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 146us/step - loss: 1.8793e-04 - mean_absolute_error: 0.0106
# Epoch 31, train: 0s, evaluation: 0s
# [Train] loss: 0.0002, metric: 0.0106
# [Dev]   loss: 0.0059, metric: 0.0598, mean: 8.447 (8.508), stdev: 1.382 (1.539)
# [Test]  loss: 0.0062, metric: 0.0605, mean: 8.386 (8.473), stdev: 1.380 (1.538)
# [DEV]   QWK:  0.849, LWK: 0.658, PRS: 0.868, SPR: 0.841, Tau: 0.705 (Best @ 24: {{0.856}}, 0.674, 0.868, 0.843, 0.707)
# [TEST]  QWK:  0.833, LWK: 0.637, PRS: 0.863, SPR: 0.835, Tau: 0.698 (Best @ 24: {{0.828}}, 0.632, 0.862, 0.835, 0.698)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 150us/step - loss: 3.8310e-04 - mean_absolute_error: 0.0154
# Epoch 32, train: 0s, evaluation: 0s
# [Train] loss: 0.0004, metric: 0.0154
# [Dev]   loss: 0.0059, metric: 0.0600, mean: 8.571 (8.508), stdev: 1.411 (1.539)
# [Test]  loss: 0.0061, metric: 0.0606, mean: 8.502 (8.473), stdev: 1.409 (1.538)
# [DEV]   QWK:  0.852, LWK: 0.658, PRS: 0.869, SPR: 0.842, Tau: 0.706 (Best @ 24: {{0.856}}, 0.674, 0.868, 0.843, 0.707)
# [TEST]  QWK:  0.856, LWK: 0.668, PRS: 0.863, SPR: 0.835, Tau: 0.698 (Best @ 24: {{0.828}}, 0.632, 0.862, 0.835, 0.698)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 149us/step - loss: 4.8051e-04 - mean_absolute_error: 0.0168
# Epoch 33, train: 0s, evaluation: 0s
# [Train] loss: 0.0005, metric: 0.0168
# [Dev]   loss: 0.0064, metric: 0.0631, mean: 8.725 (8.508), stdev: 1.382 (1.539)
# [Test]  loss: 0.0064, metric: 0.0624, mean: 8.668 (8.473), stdev: 1.379 (1.538)
# [DEV]   QWK:  0.830, LWK: 0.616, PRS: 0.867, SPR: 0.844, Tau: 0.708 (Best @ 24: {{0.856}}, 0.674, 0.868, 0.843, 0.707)
# [TEST]  QWK:  0.846, LWK: 0.661, PRS: 0.864, SPR: 0.837, Tau: 0.701 (Best @ 24: {{0.828}}, 0.632, 0.862, 0.835, 0.698)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 147us/step - loss: 4.7426e-04 - mean_absolute_error: 0.0166
# Epoch 34, train: 0s, evaluation: 0s
# [Train] loss: 0.0005, metric: 0.0166
# [Dev]   loss: 0.0061, metric: 0.0611, mean: 8.419 (8.508), stdev: 1.468 (1.539)
# [Test]  loss: 0.0063, metric: 0.0616, mean: 8.350 (8.473), stdev: 1.470 (1.538)
# [DEV]   QWK:  0.858, LWK: 0.664, PRS: 0.868, SPR: 0.843, Tau: 0.708 (Best @ 34: {{0.858}}, 0.664, 0.868, 0.843, 0.708)
# [TEST]  QWK:  0.841, LWK: 0.644, PRS: 0.864, SPR: 0.837, Tau: 0.701 (Best @ 34: {{0.841}}, 0.644, 0.864, 0.837, 0.701)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 148us/step - loss: 9.5560e-04 - mean_absolute_error: 0.0242
# Epoch 35, train: 0s, evaluation: 0s
# [Train] loss: 0.0010, metric: 0.0242
# [Dev]   loss: 0.0063, metric: 0.0624, mean: 8.703 (8.508), stdev: 1.398 (1.539)
# [Test]  loss: 0.0064, metric: 0.0621, mean: 8.640 (8.473), stdev: 1.399 (1.538)
# [DEV]   QWK:  0.831, LWK: 0.619, PRS: 0.867, SPR: 0.844, Tau: 0.708 (Best @ 34: {{0.858}}, 0.664, 0.868, 0.843, 0.708)
# [TEST]  QWK:  0.848, LWK: 0.661, PRS: 0.863, SPR: 0.836, Tau: 0.700 (Best @ 34: {{0.841}}, 0.644, 0.864, 0.837, 0.701)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 146us/step - loss: 0.0015 - mean_absolute_error: 0.0306
# Epoch 36, train: 0s, evaluation: 0s
# [Train] loss: 0.0015, metric: 0.0306
# [Dev]   loss: 0.0060, metric: 0.0604, mean: 8.633 (8.508), stdev: 1.381 (1.539)
# [Test]  loss: 0.0062, metric: 0.0609, mean: 8.568 (8.473), stdev: 1.373 (1.538)
# [DEV]   QWK:  0.848, LWK: 0.648, PRS: 0.869, SPR: 0.842, Tau: 0.707 (Best @ 34: {{0.858}}, 0.664, 0.868, 0.843, 0.708)
# [TEST]  QWK:  0.850, LWK: 0.673, PRS: 0.863, SPR: 0.835, Tau: 0.698 (Best @ 34: {{0.841}}, 0.644, 0.864, 0.837, 0.701)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 144us/step - loss: 0.0013 - mean_absolute_error: 0.0272
# Epoch 37, train: 0s, evaluation: 0s
# [Train] loss: 0.0013, metric: 0.0272
# [Dev]   loss: 0.0059, metric: 0.0600, mean: 8.494 (8.508), stdev: 1.396 (1.539)
# [Test]  loss: 0.0060, metric: 0.0599, mean: 8.435 (8.473), stdev: 1.393 (1.538)
# [DEV]   QWK:  0.854, LWK: 0.659, PRS: 0.868, SPR: 0.846, Tau: 0.711 (Best @ 34: {{0.858}}, 0.664, 0.868, 0.843, 0.708)
# [TEST]  QWK:  0.850, LWK: 0.664, PRS: 0.865, SPR: 0.837, Tau: 0.701 (Best @ 34: {{0.841}}, 0.644, 0.864, 0.837, 0.701)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 147us/step - loss: 6.1657e-04 - mean_absolute_error: 0.0184
# Epoch 38, train: 0s, evaluation: 0s
# [Train] loss: 0.0006, metric: 0.0184
# [Dev]   loss: 0.0061, metric: 0.0610, mean: 8.666 (8.508), stdev: 1.382 (1.539)
# [Test]  loss: 0.0062, metric: 0.0610, mean: 8.607 (8.473), stdev: 1.382 (1.538)
# [DEV]   QWK:  0.841, LWK: 0.637, PRS: 0.869, SPR: 0.846, Tau: 0.711 (Best @ 34: {{0.858}}, 0.664, 0.868, 0.843, 0.708)
# [TEST]  QWK:  0.851, LWK: 0.671, PRS: 0.864, SPR: 0.837, Tau: 0.701 (Best @ 34: {{0.841}}, 0.644, 0.864, 0.837, 0.701)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 152us/step - loss: 2.9289e-04 - mean_absolute_error: 0.0119
# Epoch 39, train: 0s, evaluation: 0s
# [Train] loss: 0.0003, metric: 0.0119
# [Dev]   loss: 0.0063, metric: 0.0624, mean: 8.723 (8.508), stdev: 1.354 (1.539)
# [Test]  loss: 0.0064, metric: 0.0622, mean: 8.664 (8.473), stdev: 1.352 (1.538)
# [DEV]   QWK:  0.831, LWK: 0.624, PRS: 0.869, SPR: 0.845, Tau: 0.711 (Best @ 34: {{0.858}}, 0.664, 0.868, 0.843, 0.708)
# [TEST]  QWK:  0.842, LWK: 0.649, PRS: 0.864, SPR: 0.836, Tau: 0.700 (Best @ 34: {{0.841}}, 0.644, 0.864, 0.837, 0.701)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 142us/step - loss: 3.4753e-04 - mean_absolute_error: 0.0149
# Epoch 40, train: 0s, evaluation: 0s
# [Train] loss: 0.0003, metric: 0.0149
# [Dev]   loss: 0.0057, metric: 0.0594, mean: 8.480 (8.508), stdev: 1.366 (1.539)
# [Test]  loss: 0.0060, metric: 0.0599, mean: 8.422 (8.473), stdev: 1.364 (1.538)
# [DEV]   QWK:  0.850, LWK: 0.659, PRS: 0.871, SPR: 0.844, Tau: 0.709 (Best @ 34: {{0.858}}, 0.664, 0.868, 0.843, 0.708)
# [TEST]  QWK:  0.837, LWK: 0.647, PRS: 0.864, SPR: 0.837, Tau: 0.700 (Best @ 34: {{0.841}}, 0.644, 0.864, 0.837, 0.701)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 148us/step - loss: 3.9349e-04 - mean_absolute_error: 0.0153
# Epoch 41, train: 0s, evaluation: 0s
# [Train] loss: 0.0004, metric: 0.0153
# [Dev]   loss: 0.0057, metric: 0.0591, mean: 8.511 (8.508), stdev: 1.357 (1.539)
# [Test]  loss: 0.0060, metric: 0.0600, mean: 8.453 (8.473), stdev: 1.353 (1.538)
# [DEV]   QWK:  0.847, LWK: 0.656, PRS: 0.870, SPR: 0.845, Tau: 0.710 (Best @ 34: {{0.858}}, 0.664, 0.868, 0.843, 0.708)
# [TEST]  QWK:  0.837, LWK: 0.643, PRS: 0.864, SPR: 0.836, Tau: 0.699 (Best @ 34: {{0.841}}, 0.644, 0.864, 0.837, 0.701)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 152us/step - loss: 4.0715e-04 - mean_absolute_error: 0.0159
# Epoch 42, train: 0s, evaluation: 0s
# [Train] loss: 0.0004, metric: 0.0159
# [Dev]   loss: 0.0067, metric: 0.0648, mean: 8.801 (8.508), stdev: 1.395 (1.539)
# [Test]  loss: 0.0068, metric: 0.0640, mean: 8.739 (8.473), stdev: 1.394 (1.538)
# [DEV]   QWK:  0.827, LWK: 0.618, PRS: 0.869, SPR: 0.845, Tau: 0.710 (Best @ 34: {{0.858}}, 0.664, 0.868, 0.843, 0.708)
# [TEST]  QWK:  0.840, LWK: 0.645, PRS: 0.864, SPR: 0.836, Tau: 0.700 (Best @ 34: {{0.841}}, 0.644, 0.864, 0.837, 0.701)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 147us/step - loss: 4.7449e-04 - mean_absolute_error: 0.0171
# Epoch 43, train: 0s, evaluation: 0s
# [Train] loss: 0.0005, metric: 0.0171
# [Dev]   loss: 0.0058, metric: 0.0596, mean: 8.561 (8.508), stdev: 1.393 (1.539)
# [Test]  loss: 0.0060, metric: 0.0601, mean: 8.503 (8.473), stdev: 1.390 (1.538)
# [DEV]   QWK:  0.847, LWK: 0.648, PRS: 0.869, SPR: 0.845, Tau: 0.711 (Best @ 34: {{0.858}}, 0.664, 0.868, 0.843, 0.708)
# [TEST]  QWK:  0.856, LWK: 0.668, PRS: 0.864, SPR: 0.836, Tau: 0.700 (Best @ 34: {{0.841}}, 0.644, 0.864, 0.837, 0.701)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 145us/step - loss: 3.7732e-04 - mean_absolute_error: 0.0137
# Epoch 44, train: 0s, evaluation: 0s
# [Train] loss: 0.0004, metric: 0.0137
# [Dev]   loss: 0.0058, metric: 0.0596, mean: 8.612 (8.508), stdev: 1.355 (1.539)
# [Test]  loss: 0.0061, metric: 0.0604, mean: 8.552 (8.473), stdev: 1.351 (1.538)
# [DEV]   QWK:  0.843, LWK: 0.641, PRS: 0.871, SPR: 0.844, Tau: 0.709 (Best @ 34: {{0.858}}, 0.664, 0.868, 0.843, 0.708)
# [TEST]  QWK:  0.847, LWK: 0.659, PRS: 0.863, SPR: 0.836, Tau: 0.699 (Best @ 34: {{0.841}}, 0.644, 0.864, 0.837, 0.701)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 149us/step - loss: 1.9007e-04 - mean_absolute_error: 0.0097
# Epoch 45, train: 0s, evaluation: 0s
# [Train] loss: 0.0002, metric: 0.0097
# [Dev]   loss: 0.0059, metric: 0.0598, mean: 8.593 (8.508), stdev: 1.401 (1.539)
# [Test]  loss: 0.0061, metric: 0.0604, mean: 8.532 (8.473), stdev: 1.404 (1.538)
# [DEV]   QWK:  0.844, LWK: 0.644, PRS: 0.870, SPR: 0.845, Tau: 0.711 (Best @ 34: {{0.858}}, 0.664, 0.868, 0.843, 0.708)
# [TEST]  QWK:  0.860, LWK: 0.671, PRS: 0.865, SPR: 0.836, Tau: 0.700 (Best @ 34: {{0.841}}, 0.644, 0.864, 0.837, 0.701)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 148us/step - loss: 1.9263e-04 - mean_absolute_error: 0.0103
# Epoch 46, train: 0s, evaluation: 0s
# [Train] loss: 0.0002, metric: 0.0103
# [Dev]   loss: 0.0058, metric: 0.0597, mean: 8.594 (8.508), stdev: 1.382 (1.539)
# [Test]  loss: 0.0061, metric: 0.0603, mean: 8.532 (8.473), stdev: 1.379 (1.538)
# [DEV]   QWK:  0.845, LWK: 0.642, PRS: 0.870, SPR: 0.845, Tau: 0.710 (Best @ 34: {{0.858}}, 0.664, 0.868, 0.843, 0.708)
# [TEST]  QWK:  0.857, LWK: 0.667, PRS: 0.864, SPR: 0.836, Tau: 0.699 (Best @ 34: {{0.841}}, 0.644, 0.864, 0.837, 0.701)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 147us/step - loss: 1.6528e-04 - mean_absolute_error: 0.0093
# Epoch 47, train: 0s, evaluation: 0s
# [Train] loss: 0.0002, metric: 0.0093
# [Dev]   loss: 0.0058, metric: 0.0597, mean: 8.603 (8.508), stdev: 1.382 (1.539)
# [Test]  loss: 0.0061, metric: 0.0604, mean: 8.543 (8.473), stdev: 1.381 (1.538)
# [DEV]   QWK:  0.845, LWK: 0.644, PRS: 0.871, SPR: 0.845, Tau: 0.710 (Best @ 34: {{0.858}}, 0.664, 0.868, 0.843, 0.708)
# [TEST]  QWK:  0.853, LWK: 0.663, PRS: 0.864, SPR: 0.836, Tau: 0.700 (Best @ 34: {{0.841}}, 0.644, 0.864, 0.837, 0.701)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 148us/step - loss: 1.2384e-04 - mean_absolute_error: 0.0078
# Epoch 48, train: 0s, evaluation: 0s
# [Train] loss: 0.0001, metric: 0.0078
# [Dev]   loss: 0.0059, metric: 0.0599, mean: 8.582 (8.508), stdev: 1.411 (1.539)
# [Test]  loss: 0.0061, metric: 0.0604, mean: 8.521 (8.473), stdev: 1.412 (1.538)
# [DEV]   QWK:  0.842, LWK: 0.643, PRS: 0.870, SPR: 0.845, Tau: 0.710 (Best @ 34: {{0.858}}, 0.664, 0.868, 0.843, 0.708)
# [TEST]  QWK:  0.858, LWK: 0.666, PRS: 0.864, SPR: 0.837, Tau: 0.700 (Best @ 34: {{0.841}}, 0.644, 0.864, 0.837, 0.701)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 1070/1070 [==============================] - 0s 149us/step - loss: 8.6910e-05 - mean_absolute_error: 0.0060
# Epoch 49, train: 0s, evaluation: 0s
# [Train] loss: 0.0001, metric: 0.0060
# [Dev]   loss: 0.0058, metric: 0.0596, mean: 8.572 (8.508), stdev: 1.398 (1.539)
# [Test]  loss: 0.0060, metric: 0.0602, mean: 8.510 (8.473), stdev: 1.398 (1.538)
# [DEV]   QWK:  0.846, LWK: 0.646, PRS: 0.871, SPR: 0.845, Tau: 0.710 (Best @ 34: {{0.858}}, 0.664, 0.868, 0.843, 0.708)
# [TEST]  QWK:  0.855, LWK: 0.664, PRS: 0.865, SPR: 0.837, Tau: 0.700 (Best @ 34: {{0.841}}, 0.644, 0.864, 0.837, 0.701)
# --------------------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------
# Missed @ Epoch 45:
#   [TEST] QWK: 0.860
# Best @ Epoch 34:
#   [DEV]  QWK: 0.858, LWK: 0.664, PRS: 0.868, SPR: 0.843, Tau: 0.708
#   [TEST] QWK: 0.841, LWK: 0.644, PRS: 0.864, SPR: 0.837, Tau: 0.701

# %%
#base_no_wordvec_cnn_dim50 = (0.827+0.806+0.817+0.822+0.835)/5
#base_no_wordvec_cnn_dim50_f3 = (0.812 + )

# %%
0.842 +
