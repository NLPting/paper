# %%
import sys
sys.path.append("..")
import numpy as np
import keras.backend as K
import nea.asap_reader as dataset 
from nea.asap_reader import read_org_dataset
import nea.utils as U
import os
from time import time
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.gpu_options.visible_device_list = "0"
set_session(tf.Session(config=config))
# Out:
# /home/nlplab/ting/anaconda3/envs/elmobilstm/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
train_path = '../../data/fold_0/train.tsv'
dev_path = '../../data/fold_0/dev.tsv'
test_path = '../../data/fold_0/test.tsv'
GLOVE_DIR = "../../../embeddings/glove/"
out_dir = 'output'
vocab_size = 4000
maxlen = 0
prompt_id = int(8)
w = np.load('my_level_vocab.npy').item()

# %%
#embeddings_index = {}
#f = open(os.path.join(GLOVE_DIR, 'glove.6B.50d.txt'), encoding = 'utf-8')
#for line in f:
#    values = line.split()
#    word = values[0]
#    coefs = np.asarray(values[1:], dtype='float32')
#    embeddings_index[word] = coefs
#f.close()

# %%
#embedding_matrix_glove = np.zeros((len(vocab), 50))
#for word, i in vocab.items():
#    embedding_vector = embeddings_index.get(word)
#    if embedding_vector is not None:
#        embedding_matrix_glove[i] = embedding_vector
#print('Null word embeddings: %d' % np.sum(np.sum(embedding_matrix_glove, axis=1) == 0))

# %%
from keras.preprocessing import sequence
# data_x is a list of lists
(train_x, train_y, train_pmt), (dev_x, dev_y, dev_pmt), (test_x, test_y, test_pmt), vocab, vocab_size, overal_maxlen, num_outputs = dataset.get_data(
(train_path, dev_path, test_path), prompt_id, vocab_size, maxlen, tokenize_text=True, to_lower=True, sort_by_len=False, vocab_path=None)

# %%
from keras.preprocessing import sequence
train_x = sequence.pad_sequences(train_x, maxlen=overal_maxlen)
dev_x = sequence.pad_sequences(dev_x, maxlen=overal_maxlen)
test_x = sequence.pad_sequences(test_x, maxlen=overal_maxlen)

# %%
train_y = np.array(train_y, dtype=K.floatx())
dev_y = np.array(dev_y, dtype=K.floatx())
test_y = np.array(test_y, dtype=K.floatx())
train_pmt = np.array(train_pmt, dtype='int32')
dev_pmt = np.array(dev_pmt, dtype='int32')
test_pmt = np.array(test_pmt, dtype='int32')
# We need the dev and test sets in the original scale for evaluation
dev_y_org = dev_y.astype(dataset.get_ref_dtype())
test_y_org = test_y.astype(dataset.get_ref_dtype())
# Convert scores to boundary of [0 1] for training and evaluation (loss calculation)
train_y = dataset.get_model_friendly_scores(train_y, train_pmt)
dev_y = dataset.get_model_friendly_scores(dev_y, dev_pmt)
test_y = dataset.get_model_friendly_scores(test_y, test_pmt)

# %%
from keras.models import Sequential, Model , Input
from keras.layers import Dense, Embedding, Activation , Flatten  , concatenate
from keras.layers.merge import Concatenate
from keras.layers import Dropout, GlobalAveragePooling1D ,GlobalMaxPooling1D , MaxPooling1D
from keras.layers import LSTM , Bidirectional , Convolution1D
from nea.optimizers import get_optimizer
from dl_text import rd_ft
import textstat

# %%
train_org = read_org_dataset(train_path , prompt_id ,tokenize_text=True, to_lower=True )
dev_org = read_org_dataset(dev_path , prompt_id ,tokenize_text=True, to_lower=True )
test_org = read_org_dataset(test_path , prompt_id ,tokenize_text=True, to_lower=True )

# %%
def lg_feature(org_array):
    return len(org_array)
def lg_level_feature(org_array):
    return len([word for word in org_array if word in w])
def differe_level_feature(org_array): #, delete_key=['A1']):
    feature_map = {'A1':0,'A2':0,'B1':0,'B2':0,'C1':0,'C2':0}
    for word in org_array:
        if word in w:
            if w[word]=='A1':feature_map['A1']+=1
            if w[word]=='A2':feature_map['A2']+=1
            if w[word]=='B1':feature_map['B1']+=1
            if w[word]=='B2':feature_map['B2']+=1
            if w[word]=='C1':feature_map['C1']+=1
            if w[word]=='C2':feature_map['C2']+=1
    #print(feature_map)
    F = [feature_map[key] for key in feature_map.keys() if key] #not in delete_key]
    return F  
def get_feature(org_array):
    corpus = ' '.join(org_array)
    f1 = lg_feature(org_array)
    f2 = lg_level_feature(org_array)
    f3 = differe_level_feature(org_array)
    f4 = textstat.flesch_reading_ease(corpus)
    f5 = textstat.smog_index(corpus)
    f6 = textstat.flesch_kincaid_grade(corpus)
    f7 = textstat.coleman_liau_index(corpus)
    f8 = textstat.automated_readability_index(corpus)
    f9 = textstat.dale_chall_readability_score(corpus)
    f10 = textstat.difficult_words(corpus)
    f11 = textstat.linsear_write_formula(corpus)
    f12 = textstat.gunning_fog(corpus)
    F = [f1,f2,*f3 ,f4,f5,f6,f7,f8,f9,f10,f11,f12]
    #F = [f1  , f2,*f3]
    return F

# %%
train_f = np.array([get_feature(x) for x in train_org] , dtype=K.floatx())
dev_f =  np.array([get_feature(x) for x in dev_org] , dtype=K.floatx())
test_f = np.array([get_feature(x) for x in test_org] , dtype=K.floatx())

# %%
loss = 'mean_squared_error'
metric = 'mean_absolute_error'
opt = get_optimizer('adam')

# %%
main_input = Input(shape=(overal_maxlen,), dtype='float64')
embedder = Embedding(len(vocab), 50, input_length = overal_maxlen) 
#embedder = (Embedding(len(vocab),50,weights=[embedding_matrix_glove],input_length=overal_maxlen,trainable=True))
embed = embedder(main_input)
cnn1 = Convolution1D(filters=50 ,kernel_size=3)(embed)
flat = Flatten()(cnn1)
#global1 = GlobalAveragePooling1D()(cnn1)
######################
Other_Input = Input(shape=(len(train_f[0]),))
add_feature = concatenate([flat, Other_Input],axis=1)
##########################################
#add_feature = Dropout(0.5)(add_feature)
main_output = Dense(1, activation='sigmoid')(add_feature)

model = Model(inputs = [main_input , Other_Input], outputs = main_output)

# %%
model.compile(loss=loss,
              optimizer=opt,
              metrics=[metric])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_34 (InputLayer)           (None, 1122)         0
# __________________________________________________________________________________________________
# embedding_18 (Embedding)        (None, 1122, 50)     200000      input_34[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 1120, 50)     7550        embedding_18[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 224, 50)      0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# flatten_18 (Flatten)            (None, 11200)        0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# input_35 (InputLayer)           (None, 17)           0
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 11217)        0           flatten_18[0][0]
#                                                                  input_35[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 1)            11218       concatenate_17[0][0]
# ==================================================================================================
# Total params: 218,768
# Trainable params: 218,768
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from nea.evalute_twoinput import Evaluator 
evl = Evaluator (dataset, prompt_id, out_dir, dev_x , dev_f  ,test_x , test_f , dev_y, test_y, dev_y_org, test_y_org)
evl.evaluate(model, -1, print_info=True)
# Out:
# [Dev]   loss: 0.3903, metric: 0.6153, mean: 0.281 (37.201), stdev: 1.125 (5.906)
# [Test]  loss: 0.3878, metric: 0.6151, mean: 0.341 (37.248), stdev: 1.237 (5.279)
# [DEV]   QWK:  -0.004, LWK: 0.000, PRS: -0.438, SPR: -0.483, Tau: -0.355 (Best @ -1: {{-0.004}}, 0.000, -0.438, -0.483, -0.355)
# [TEST]  QWK:  -0.003, LWK: 0.000, PRS: -0.360, SPR: -0.520, Tau: -0.375 (Best @ -1: {{-0.003}}, 0.000, -0.360, -0.520, -0.375)
# --------------------------------------------------------------------------------------------------------------------------

# %%
total_train_time = 0
total_eval_time = 0
best , count = 0 , 0
for ii in range(100):
    # Training
    t0 = time()
    train_history = model.fit([train_x , train_f], train_y, batch_size=32, epochs=1, verbose=1)
    #train_history = model.fit([train_f], train_y, batch_size=32, epochs=1, verbose=1)
    tr_time = time() - t0
    total_train_time += tr_time
    # Evaluate
    t0 = time()
    evl.evaluate(model, ii)
    evl_time = time() - t0
    total_eval_time += evl_time
    train_loss = train_history.history['loss'][0]
    train_metric = train_history.history[metric][0]
    print('Epoch %d, train: %is, evaluation: %is' % (ii, tr_time, evl_time))
    print('[Train] loss: %.4f, metric: %.4f' % (train_loss, train_metric))
    evl.dev_qwk
    evl.print_info()
    if evl.dev_qwk > best:
        best = evl.dev_qwk
        count=0
    else:
        count+=1 
evl.print_final_info()
# Out:
# Epoch 1/1
# 434/434 [==============================] - 0s 1ms/step - loss: 0.1615 - mean_absolute_error: 0.3782
# Epoch 0, train: 0s, evaluation: 0s
# [Train] loss: 0.1615, metric: 0.3782
# [Dev]   loss: 0.1432, metric: 0.3675, mean: 57.743 (37.201), stdev: 10.741 (5.906)
# [Test]  loss: 0.1483, metric: 0.3754, mean: 57.714 (37.248), stdev: 11.019 (5.279)
# [DEV]   QWK:  0.099, LWK: 0.043, PRS: 0.445, SPR: 0.389, Tau: 0.328 (Best @ 0: {{0.099}}, 0.043, 0.445, 0.389, 0.328)
# [TEST]  QWK:  0.060, LWK: 0.027, PRS: 0.294, SPR: 0.498, Tau: 0.410 (Best @ 0: {{0.060}}, 0.027, 0.294, 0.498, 0.410)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 434/434 [==============================] - 0s 169us/step - loss: 0.1534 - mean_absolute_error: 0.3807
# Epoch 1, train: 0s, evaluation: 0s
# [Train] loss: 0.1534, metric: 0.3807
# [Dev]   loss: 0.1541, metric: 0.3800, mean: 60.000 (37.201), stdev: 0.004 (5.906)
# [Test]  loss: 0.1512, metric: 0.3789, mean: 59.981 (37.248), stdev: 0.225 (5.279)
# [DEV]   QWK:  0.000, LWK: 0.000, PRS: 0.165, SPR: 0.198, Tau: 0.166 (Best @ 0: {{0.099}}, 0.043, 0.445, 0.389, 0.328)
# [TEST]  QWK:  0.001, LWK: -0.000, PRS: 0.146, SPR: 0.205, Tau: 0.173 (Best @ 0: {{0.060}}, 0.027, 0.294, 0.498, 0.410)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 434/434 [==============================] - 0s 171us/step - loss: 0.1566 - mean_absolute_error: 0.3842
# Epoch 2, train: 0s, evaluation: 0s
# [Train] loss: 0.1566, metric: 0.3842
# [Dev]   loss: 0.1541, metric: 0.3800, mean: 60.000 (37.201), stdev: 0.000 (5.906)
# [Test]  loss: 0.1515, metric: 0.3792, mean: 59.999 (37.248), stdev: 0.014 (5.279)
# [DEV]   QWK:  0.000, LWK: 0.000, PRS: 0
(Best @ 8: {{0.142}}, 0.062, 0.452, 0.496, 0.413)
# [TEST]  QWK:  0.019, LWK: 0.008, PRS: 0.177, SPR: 0.205, Tau: 0.173 (Best @ 8: {{0.176}}, 0.080, 0.538, 0.535, 0.435)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 434/434 [==============================] - 0s 168us/step - loss: 0.1539 - mean_absolute_error: 0.3812
# Epoch 34, train: 0s, evaluation: 0s
# [Train] loss: 0.1539, metric: 0.3812
# [Dev]   loss: 0.1520, metric: 0.3776, mean: 59.648 (37.201), stdev: 4.064 (5.906)
# [Test]  loss: 0.1505, metric: 0.3781, mean: 59.551 (37.248), stdev: 4.969 (5.279)
# [DEV]   QWK:  0.015, LWK: 0.007, PRS: 0.167, SPR: 0.198, Tau: 0.166 (Best @ 8: {{0.142}}, 0.062, 0.452, 0.496, 0.413)
# [TEST]  QWK:  0.015, LWK: 0.006, PRS: 0.153, SPR: 0.205, Tau: 0.173 (Best @ 8: {{0.176}}, 0.080, 0.538, 0.535, 0.435)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 434/434 [==============================] - 0s 167us/step - loss: 0.1545 - mean_absolute_error: 0.3823
# Epoch 35, train: 0s, evaluation: 0s
# [Train] loss: 0.1545, metric: 0.3823
# [Dev]   loss: 0.1521, metric: 0.3779, mean: 59.592 (37.201), stdev: 4.549 (5.906)
# [Test]  loss: 0.1501, metric: 0.3775, mean: 59.510 (37.248), stdev: 5.019 (5.279)
# [DEV]   QWK:  0.017, LWK: 0.007, PRS: 0.177, SPR: 0.198, Tau: 0.166 (Best @ 8: {{0.142}}, 0.062, 0.452, 0.496, 0.413)
# [TEST]  QWK:  0.015, LWK: 0.006, PRS: 0.159, SPR: 0.205, Tau: 0.173 (Best @ 8: {{0.176}}, 0.080, 0.538, 0.535, 0.435)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 434/434 [==============================] - 0s 169us/step - loss: 0.1538 - mean_absolute_error: 0.3812
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-131-796a16b168bd> in <module>
#      11     # Evaluate
#      12     t0 = time()
# ---> 13     evl.evaluate(model, ii)
#      14     evl_time = time() - t0
#      15     total_eval_time += evl_time
#
# ~/Automated_Essay_Scoring/experiment/nea/evalute_twoinput.py in evaluate(self, model, epoch, print_info)
#      67         self.dump_predictions(self.dev_pred, self.test_pred, epoch)
#      68
# ---> 69         self.dev_prs, self.test_prs, self.dev_spr, self.test_spr, self.dev_tau, self.test_tau = self.calc_correl(self.dev_pred, self.test_pred)
#      70
#      71         self.dev_qwk, self.test_qwk, self.dev_lwk, self.test_lwk = self.calc_qwk(self.dev_pred, self.test_pred)
#
# ~/Automated_Essay_Scoring/experiment/nea/evalute_twoinput.py in calc_correl(self, dev_pred, test_pred)
#      38         dev_prs, _ = pearsonr(dev_pred, self.dev_y_org)
#      39         test_prs, _ = pearsonr(test_pred, self.test_y_org)
# ---> 40         dev_spr, _ = spearmanr(dev_pred, self.dev_y_org)
#      41         test_spr, _ = spearmanr(test_pred, self.test_y_org)
#      42         dev_tau, _ = kendalltau(dev_pred, self.dev_y_org)
#
# ~/anaconda3/envs/elmobilstm/lib/python3.6/site-packages/scipy/stats/stats.py in spearmanr(a, b, axis, nan_policy)
#    3317         np.seterr(**olderr)
#    3318
# -> 3319     prob = 2 * distributions.t.sf(np.abs(t), n-2)
#    3320
#    3321     if rs.shape == (2, 2):
#
# KeyboardInterrupt:

# %%
#base_no_wordvec_cnn_dim50 = (0.827+0.806+0.817+0.822+0.835)/5
#base_no_wordvec_cnn_dim50_f3 = (0.812 + )

# %%
0.842 +
