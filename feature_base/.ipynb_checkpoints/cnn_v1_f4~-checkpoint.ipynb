# %%
import sys
sys.path.append("..")
import numpy as np
import keras.backend as K
import nea.asap_reader as dataset 
from nea.asap_reader import read_org_dataset
import nea.utils as U
import os
from time import time
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.gpu_options.visible_device_list = "1"
set_session(tf.Session(config=config))
# Out:
# /home/nlplab/ting/anaconda3/envs/elmobilstm/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
train_path = '../../data/fold_4/train.tsv'
dev_path = '../../data/fold_4/dev.tsv'
test_path = '../../data/fold_4/test.tsv'
GLOVE_DIR = "../../../embeddings/glove/"
out_dir = 'output'
vocab_size = 4000
maxlen = 0
prompt_id = int(8)
w = np.load('my_level_vocab.npy').item()

# %%
#embeddings_index = {}
#f = open(os.path.join(GLOVE_DIR, 'glove.6B.50d.txt'), encoding = 'utf-8')
#for line in f:
#    values = line.split()
#    word = values[0]
#    coefs = np.asarray(values[1:], dtype='float32')
#    embeddings_index[word] = coefs
#f.close()

# %%
#embedding_matrix_glove = np.zeros((len(vocab), 50))
#for word, i in vocab.items():
#    embedding_vector = embeddings_index.get(word)
#    if embedding_vector is not None:
#        embedding_matrix_glove[i] = embedding_vector
#print('Null word embeddings: %d' % np.sum(np.sum(embedding_matrix_glove, axis=1) == 0))

# %%
from keras.preprocessing import sequence
# data_x is a list of lists
(train_x, train_y, train_pmt), (dev_x, dev_y, dev_pmt), (test_x, test_y, test_pmt), vocab, vocab_size, overal_maxlen, num_outputs = dataset.get_data(
(train_path, dev_path, test_path), prompt_id, vocab_size, maxlen, tokenize_text=True, to_lower=True, sort_by_len=False, vocab_path=None)

# %%
from keras.preprocessing import sequence
train_x = sequence.pad_sequences(train_x, maxlen=overal_maxlen)
dev_x = sequence.pad_sequences(dev_x, maxlen=overal_maxlen)
test_x = sequence.pad_sequences(test_x, maxlen=overal_maxlen)

# %%
train_y = np.array(train_y, dtype=K.floatx())
dev_y = np.array(dev_y, dtype=K.floatx())
test_y = np.array(test_y, dtype=K.floatx())
train_pmt = np.array(train_pmt, dtype='int32')
dev_pmt = np.array(dev_pmt, dtype='int32')
test_pmt = np.array(test_pmt, dtype='int32')
# We need the dev and test sets in the original scale for evaluation
dev_y_org = dev_y.astype(dataset.get_ref_dtype())
test_y_org = test_y.astype(dataset.get_ref_dtype())
# Convert scores to boundary of [0 1] for training and evaluation (loss calculation)
train_y = dataset.get_model_friendly_scores(train_y, train_pmt)
dev_y = dataset.get_model_friendly_scores(dev_y, dev_pmt)
test_y = dataset.get_model_friendly_scores(test_y, test_pmt)

# %%
from keras.models import Sequential, Model , Input
from keras.layers import Dense, Embedding, Activation , Flatten  , concatenate
from keras.layers.merge import Concatenate
from keras.layers import Dropout, GlobalAveragePooling1D ,GlobalMaxPooling1D , MaxPooling1D , AveragePooling1D
from keras.layers import LSTM , Bidirectional , Convolution1D
from nea.optimizers import get_optimizer
from dl_text import rd_ft
import textstat

# %%
train_org = read_org_dataset(train_path , prompt_id ,tokenize_text=True, to_lower=True )
dev_org = read_org_dataset(dev_path , prompt_id ,tokenize_text=True, to_lower=True )
test_org = read_org_dataset(test_path , prompt_id ,tokenize_text=True, to_lower=True )

# %%
def lg_feature(org_array):
    return len(org_array)
def lg_level_feature(org_array):
    return len([word for word in org_array if word in w and w[word]!='A1' and w[word]!='A2'])
def differe_level_feature(org_array , delete_key=['A1','A2']):
    feature_map = {'A1':0,'A2':0,'B1':0,'B2':0,'C1':0,'C2':0}
    for word in org_array:
        if word in w:
            if w[word]=='A1':feature_map['A1']+=1
            if w[word]=='A2':feature_map['A2']+=1
            if w[word]=='B1':feature_map['B1']+=1
            if w[word]=='B2':feature_map['B2']+=1
            if w[word]=='C1':feature_map['C1']+=1
            if w[word]=='C2':feature_map['C2']+=1
    #print(feature_map)
    F = [feature_map[key] for key in feature_map.keys() if key not in delete_key]
    return F  
def get_feature(org_array):
    corpus = ' '.join(org_array)
    f1 = lg_feature(org_array)
    f2 = lg_level_feature(org_array)
    f3 = differe_level_feature(org_array)
    f4 = textstat.flesch_reading_ease(corpus)
    f5 = textstat.smog_index(corpus)
    f6 = textstat.flesch_kincaid_grade(corpus)
    f7 = textstat.coleman_liau_index(corpus)
    f8 = textstat.automated_readability_index(corpus)
    f9 = textstat.dale_chall_readability_score(corpus)
    f10 = textstat.difficult_words(corpus)
    f11 = textstat.linsear_write_formula(corpus)
    f12 = textstat.gunning_fog(corpus)
    #F = [f2,*f3,f6,f7,f8,f9,f10,f11,f12]
    #F = [f2,*f3 , f6  , f8 , f9 , f10]
    #F = [f1 , f2,*f3]
    F= [*f3]
    #F = [f1]
    return F

# %%
train_f = np.array([get_feature(x) for x in train_org] , dtype=K.floatx())
dev_f =  np.array([get_feature(x) for x in dev_org] , dtype=K.floatx())
test_f = np.array([get_feature(x) for x in test_org] , dtype=K.floatx())

# %%
main_input = Input(shape=(overal_maxlen,), dtype='float64')
embedder = Embedding(len(vocab), 50, input_length = overal_maxlen) 
#embedder = (Embedding(len(vocab),50,weights=[embedding_matrix_glove],input_length=overal_maxlen,trainable=True))
embed = embedder(main_input)
cnn1 = Convolution1D(filters=50 ,kernel_size=3)(embed)
#cnn1 = AveragePooling1D()(cnn1)
flat = Flatten()(cnn1)
#global1 = GlobalAveragePooling1D()(cnn1)
######################
Other_Input = Input(shape=(len(train_f[0]),))
add_feature = concatenate([flat, Other_Input],axis=1)
##########################################
main_output = Dense(1, activation='sigmoid')(add_feature)

model = Model(inputs = [main_input , Other_Input], outputs = main_output)

# %%
loss = 'mean_squared_error'
metric = 'mean_absolute_error'
opt = get_optimizer('adam')

# %%
model.compile(loss=loss,
              optimizer=opt,
              metrics=[metric])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 1122)         0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 1122, 50)     200000      input_5[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 1120, 50)     7550        embedding_3[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 56000)        0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# input_6 (InputLayer)            (None, 4)            0
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 56004)        0           flatten_3[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            56005       concatenate_3[0][0]
# ==================================================================================================
# Total params: 263,555
# Trainable params: 263,555
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from nea.evalute_twoinput import Evaluator 
evl = Evaluator (dataset, prompt_id, out_dir, dev_x , dev_f  ,test_x , test_f , dev_y, test_y, dev_y_org, test_y_org)
evl.evaluate(model, -1, print_info=True)
# Out:
# [Dev]   loss: 0.0420, metric: 0.1840, mean: 26.501 (37.069), stdev: 1.633 (5.347)
# [Test]  loss: 0.0436, metric: 0.1827, mean: 26.717 (37.201), stdev: 1.545 (5.906)
# [DEV]   QWK:  -0.057, LWK: -0.012, PRS: -0.478, SPR: -0.490, Tau: -0.359 (Best @ -1: {{-0.057}}, -0.012, -0.478, -0.490, -0.359)
# [TEST]  QWK:  -0.067, LWK: -0.020, PRS: -0.538, SPR: -0.546, Tau: -0.397 (Best @ -1: {{-0.067}}, -0.020, -0.538, -0.546, -0.397)
# --------------------------------------------------------------------------------------------------------------------------

# %%
total_train_time = 0
total_eval_time = 0
best , count = 0 , 0
for ii in range(70):
    # Training
    t0 = time()
    train_history = model.fit([train_x , train_f], train_y, batch_size=32, epochs=1, verbose=1)
    #train_history = model.fit([train_f], train_y, batch_size=32, epochs=1, verbose=1)
    tr_time = time() - t0
    total_train_time += tr_time
    # Evaluate
    t0 = time()
    evl.evaluate(model, ii)
    evl_time = time() - t0
    total_eval_time += evl_time
    train_loss = train_history.history['loss'][0]
    train_metric = train_history.history[metric][0]
    print('Epoch %d, train: %is, evaluation: %is' % (ii, tr_time, evl_time))
    print('[Train] loss: %.4f, metric: %.4f' % (train_loss, train_metric))
    evl.print_info()
    
evl.print_final_info()
# Out:
# Epoch 1/1
# 435/435 [==============================] - 0s 597us/step - loss: 0.0157 - mean_absolute_error: 0.0992
# Epoch 0, train: 0s, evaluation: 0s
# [Train] loss: 0.0157, metric: 0.0992
# [Dev]   loss: 0.0061, metric: 0.0619, mean: 36.308 (37.069), stdev: 3.137 (5.347)
# [Test]  loss: 0.0067, metric: 0.0643, mean: 36.682 (37.201), stdev: 3.226 (5.906)
# [DEV]   QWK:  0.431, LWK: 0.233, PRS: 0.503, SPR: 0.417, Tau: 0.304 (Best @ 0: {{0.431}}, 0.233, 0.503, 0.417, 0.304)
# [TEST]  QWK:  0.471, LWK: 0.271, PRS: 0.558, SPR: 0.487, Tau: 0.358 (Best @ 0: {{0.471}}, 0.271, 0.558, 0.487, 0.358)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 435/435 [==============================] - 0s 165us/step - loss: 0.0040 - mean_absolute_error: 0.0491
# Epoch 1, train: 0s, evaluation: 0s
# [Train] loss: 0.0040, metric: 0.0491
# [Dev]   loss: 0.0056, metric: 0.0595, mean: 36.131 (37.069), stdev: 2.451 (5.347)
# [Test]  loss: 0.0065, metric: 0.0610, mean: 36.270 (37.201), stdev: 2.586 (5.906)
# [DEV]   QWK:  0.422, LWK: 0.228, PRS: 0.578, SPR: 0.513, Tau: 0.380 (Best @ 0: {{0.431}}, 0.233, 0.503, 0.417, 0.304)
# [TEST]  QWK:  0.452, LWK: 0.284, PRS: 0.627, SPR: 0.600, Tau: 0.448 (Best @ 0: {{0.471}}, 0.271, 0.558, 0.487, 0.358)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 435/435 [==============================] - 0s 167us/step - loss: 0.0017 - mean_absolute_error: 0.0312
# Epoch 2, train: 0s, evaluation: 0s
# [Train] loss: 0.0017, metric: 0.0312
# [Dev]   loss: 0.0065, metric: 0.0643, mean: 35.347 (37.069), stdev: 2.275 (5.347)
# [Test]  loss: 0.0072, metric: 0.0644, mean: 35.341 (37.201), stdev: 2.464 (5.906)
# [DEV]   QWK:  0.372, LWK: 0.202, PRS: 0.548, SPR: 0.465, Tau: 0.338 (Best @ 0: {{0.431}}, 0.233, 0.503, 0.417, 0.304)
# [TEST]  QWK:  0.414, LWK: 0.258, PRS: 0.634, SPR: 0.599, Tau: 0.445 (Best @ 0: {{0.471}}, 0.271, 0.558, 0.487, 0.358)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 435/435 [==============================] - 0s 165us/step - loss: 6.8341e-04 - mean_absolute_error: 0.0190
# Epoch 3, train: 0s, evaluation: 0s
# [Train] loss: 0.0007, metric: 0.0190
# [Dev]   loss: 0.0061, metric: 0.0621, mean: 35.838 (37.069), stdev: 2.470 (5.347)
# [Test]  loss: 0.0066, metric: 0.0623, mean: 35.849 (37.201), stdev: 2.687 (5.906)
# [DEV]   QWK:  0.385, LWK: 0.203, PRS: 0.544, SPR: 0.457, Tau: 0.336 (Best @ 0: {{0.431}}, 0.233, 0.503, 0.417, 0.304)
# [TEST]  QWK:  0
train: 0s, evaluation: 0s
# [Train] loss: 0.0000, metric: 0.0025
# [Dev]   loss: 0.0054, metric: 0.0577, mean: 36.591 (37.069), stdev: 2.866 (5.347)
# [Test]  loss: 0.0058, metric: 0.0593, mean: 36.605 (37.201), stdev: 2.988 (5.906)
# [DEV]   QWK:  0.472, LWK: 0.264, PRS: 0.570, SPR: 0.511, Tau: 0.377 (Best @ 35: {{0.479}}, 0.265, 0.561, 0.491, 0.362)
# [TEST]  QWK:  0.526, LWK: 0.315, PRS: 0.655, SPR: 0.642, Tau: 0.478 (Best @ 35: {{0.547}}, 0.315, 0.638, 0.620, 0.461)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 435/435 [==============================] - 0s 155us/step - loss: 1.2665e-05 - mean_absolute_error: 0.0024
# Epoch 51, train: 0s, evaluation: 0s
# [Train] loss: 0.0000, metric: 0.0024
# [Dev]   loss: 0.0055, metric: 0.0579, mean: 36.440 (37.069), stdev: 2.859 (5.347)
# [Test]  loss: 0.0059, metric: 0.0594, mean: 36.455 (37.201), stdev: 2.984 (5.906)
# [DEV]   QWK:  0.468, LWK: 0.260, PRS: 0.572, SPR: 0.514, Tau: 0.381 (Best @ 35: {{0.479}}, 0.265, 0.561, 0.491, 0.362)
# [TEST]  QWK:  0.533, LWK: 0.324, PRS: 0.655, SPR: 0.641, Tau: 0.478 (Best @ 35: {{0.547}}, 0.315, 0.638, 0.620, 0.461)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 435/435 [==============================] - 0s 160us/step - loss: 1.7234e-05 - mean_absolute_error: 0.0025
# Epoch 52, train: 0s, evaluation: 0s
# [Train] loss: 0.0000, metric: 0.0025
# [Dev]   loss: 0.0054, metric: 0.0577, mean: 36.548 (37.069), stdev: 2.882 (5.347)
# [Test]  loss: 0.0059, metric: 0.0593, mean: 36.566 (37.201), stdev: 3.006 (5.906)
# [DEV]   QWK:  0.473, LWK: 0.263, PRS: 0.571, SPR: 0.510, Tau: 0.378 (Best @ 35: {{0.479}}, 0.265, 0.561, 0.491, 0.362)
# [TEST]  QWK:  0.530, LWK: 0.320, PRS: 0.654, SPR: 0.640, Tau: 0.477 (Best @ 35: {{0.547}}, 0.315, 0.638, 0.620, 0.461)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 435/435 [==============================] - 0s 166us/step - loss: 1.3346e-05 - mean_absolute_error: 0.0023
# Epoch 53, train: 0s, evaluation: 0s
# [Train] loss: 0.0000, metric: 0.0023
# [Dev]   loss: 0.0054, metric: 0.0578, mean: 36.498 (37.069), stdev: 2.875 (5.347)
# [Test]  loss: 0.0059, metric: 0.0593, mean: 36.510 (37.201), stdev: 2.997 (5.906)
# [DEV]   QWK:  0.475, LWK: 0.267, PRS: 0.572, SPR: 0.514, Tau: 0.381 (Best @ 35: {{0.479}}, 0.265, 0.561, 0.491, 0.362)
# [TEST]  QWK:  0.533, LWK: 0.324, PRS: 0.656, SPR: 0.641, Tau: 0.478 (Best @ 35: {{0.547}}, 0.315, 0.638, 0.620, 0.461)
# --------------------------------------------------------------------------------------------------------------------------
# Epoch 1/1
# 435/435 [==============================] - 0s 158us/step - loss: 7.0678e-06 - mean_absolute_error: 0.0017

# %%
#base_no_wordvec_cnn_dim50 = (0.827+0.806+0.817+0.822+0.835)/5
#base_no_wordvec_cnn_dim50_f3 = (0.812 + )

# %%
[3]

# %%
pr1 = (0.857 + 0.818 + 0.841 + 0.84 + 0.837) /5 
pr1
# Out:
# 0.8385999999999999

# %%
pr2 = (0.665 + 0.692 + 0.671 + 0.667 +  0.705) / 5
pr2
# Out:
# 0.68

# %%
pr3 = (0.685 + 0.67 + 0.662 + 0.698 + 0.675) / 5
pr3
# Out:
# 0.6779999999999999

# %%
pr4 = (0.796 + 0.803 + 0.776 + 0.795 + 0.759 ) /5
pr4
# Out:
# 0.7857999999999999

# %%
pr5 = (0.817 + 0.820 + 0.821 + 0.802 + 0.811)/5
pr5
# Out:
# 0.8142000000000001

# %%
pr6 = (0.801 + 0.79  + 0.783  + 0.808 + 0.812 )/5
pr6
# Out:
# 0.7988000000000002

# %%
pr7 = (0.767 + 0.763 + 0.808 + 0.796 + 0.788)/ 5
pr7
# Out:
# 0.7844000000000001

# %%
p8 = (0.614 + 0.59 + 0.636 + 0.563 +   )
